# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:\\Users\\kohit\\Downloads\\diabetes.csv")

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
data.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 274           13      106             70              0        0  34.2
# 251            2      129             84              0        0  28.0
# 561            0      198             66             32      274  41.3
# 310            6       80             66             30        0  26.2
# 375           12      140             82             43      325  39.2
# 400            4       95             64              0        0  32.0
# 384            1      125             70             24      110  24.3
# 555            7      124             70             33      215  25.5
# 359            1      196             76             36      249  36.5
# 218            5       85             74             22        0  29.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 274                     0.251   52        0
# 251                     0.284   27        0
# 561                     0.502   28        1
# ...

# %%
data.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
column_names = list(data)

# %%
column_names
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
data.isnull().sum()  #here we are getting output as 00 because there is no null as all null are occupied by 0 and Nan
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data[column_names[1:6]] == 0
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin    BMI
# 0      False          False          False     True  False
# 1      False          False          False     True  False
# 2      False          False           True     True  False
# 3      False          False          False    False  False
# 4      False          False          False    False  False
# ..       ...            ...            ...      ...    ...
# 763    False          False          False    False  False
# 764    False          False          False     True  False
# 765    False          False          False    False  False
# 766    False          False           True     True  False
# 767    False          False          False     True  False
#
# [768 rows x 5 columns]

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data[column_names[1:6]] == 0
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin    BMI
# 0      False          False          False     True  False
# 1      False          False          False     True  False
# 2      False          False           True     True  False
# 3      False          False          False    False  False
# 4      False          False          False    False  False
# ..       ...            ...            ...      ...    ...
# 763    False          False          False    False  False
# 764    False          False          False     True  False
# 765    False          False          False    False  False
# 766    False          False           True     True  False
# 767    False          False          False     True  False
#
# [768 rows x 5 columns]

# %%
data[column_names[1:6]]  = data[column_names[1:6]].replace(0,np.nan)

# %%
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0      NaN  33.6
# 1            1     85.0           66.0           29.0      NaN  26.6
# 2            8    183.0           64.0            NaN      NaN  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
# 5            5    116.0           74.0            NaN      NaN  25.6
# 6            3     78.0           50.0           32.0     88.0  31.0
# 7           10    115.0            NaN            NaN      NaN  35.3
# 8            2    197.0           70.0           45.0    543.0  30.5
# 9            8    125.0           96.0            NaN      NaN   NaN
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
(data.isnull().mean())  #it will give us the % of null values present in data
# Out:
# Pregnancies                 0.000000
# Glucose                     0.006510
# BloodPressure               0.045573
# SkinThickness               0.295573
# Insulin                     0.486979
# BMI                         0.014323
# DiabetesPedigreeFunction    0.000000
# Age                         0.000000
# Outcome                     0.000000
# dtype: float64

# %%
data.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
data.dropna(inplace = True)
print("data after dropna", data.shape)
# Out:
# data after dropna (392, 9)

# %%
data.head(10)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3             1     89.0           66.0           23.0     94.0  28.1
# 4             0    137.0           40.0           35.0    168.0  43.1
# 6             3     78.0           50.0           32.0     88.0  31.0
# 8             2    197.0           70.0           45.0    543.0  30.5
# 13            1    189.0           60.0           23.0    846.0  30.1
# 14            5    166.0           72.0           19.0    175.0  25.8
# 16            0    118.0           84.0           47.0    230.0  45.8
# 18            1    103.0           30.0           38.0     83.0  43.3
# 19            1    115.0           70.0           30.0     96.0  34.6
# 20            3    126.0           88.0           41.0    235.0  39.3
#
#     DiabetesPedigreeFunction  Age  Outcome
# 3                      0.167   21        0
# 4                      2.288   33        1
# 6                      0.248   26        1
# ...

# %% [markdown]
# ***ANOTHER WAY OF DETECTING/REMOVING NULL,BLANK_STRING,'?', EMPTY_STRING***

# %%
data1 = pd.read_csv("C:\\Users\\kohit\\Downloads\\diabetes.csv")

# %%
data1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
column_names1 = list(data1)

# %%
column_names1
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
data1[column_names1[1:6]] = data1[column_names1[1:6]].replace(0,np.nan)

# %%
data1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data1 = data1.replace('nan',np.nan).fillna('?')   #### IN THIS CODE REPLACE WILL CONVERT PROPER 'NAN' STRING TO NP.NAN -->(NULL)
                                                  #### AND THAN FILLNA('?') WILL CONVERT ALL NULL TO "?" IN WHOLE DATA1

# %%
data1
# Out:
#      Pregnancies Glucose BloodPressure SkinThickness Insulin   BMI  \
# 0              6   148.0          72.0          35.0       ?  33.6
# 1              1    85.0          66.0          29.0       ?  26.6
# 2              8   183.0          64.0             ?       ?  23.3
# 3              1    89.0          66.0          23.0    94.0  28.1
# 4              0   137.0          40.0          35.0   168.0  43.1
# ..           ...     ...           ...           ...     ...   ...
# 763           10   101.0          76.0          48.0   180.0  32.9
# 764            2   122.0          70.0          27.0       ?  36.8
# 765            5   121.0          72.0          23.0   112.0  26.2
# 766            1   126.0          60.0             ?       ?  30.1
# 767            1    93.0          70.0          31.0       ?  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# ...

# %%
data1.to_csv("dibatic data sample.csv" , index = False)

# %%
data1= pd.read_csv("dibatic data sample.csv")

# %%
data1
# Out:
#      Pregnancies Glucose BloodPressure SkinThickness Insulin   BMI  \
# 0              6   148.0          72.0          35.0       ?  33.6
# 1              1    85.0          66.0          29.0       ?  26.6
# 2              8   183.0          64.0             ?       ?  23.3
# 3              1    89.0          66.0          23.0    94.0  28.1
# 4              0   137.0          40.0          35.0   168.0  43.1
# ..           ...     ...           ...           ...     ...   ...
# 763           10   101.0          76.0          48.0   180.0  32.9
# 764            2   122.0          70.0          27.0       ?  36.8
# 765            5   121.0          72.0          23.0   112.0  26.2
# 766            1   126.0          60.0             ?       ?  30.1
# 767            1    93.0          70.0          31.0       ?  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# ...

# %%
data2 = pd.read_csv("dibatic data sample.csv", na_values = '?')

# %%
data2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data2 = data2.drop('Glucose' , axis =1)

# %%
data2
# Out:
#      Pregnancies  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6           72.0           35.0      NaN  33.6
# 1              1           66.0           29.0      NaN  26.6
# 2              8           64.0            NaN      NaN  23.3
# 3              1           66.0           23.0     94.0  28.1
# 4              0           40.0           35.0    168.0  43.1
# ..           ...            ...            ...      ...   ...
# 763           10           76.0           48.0    180.0  32.9
# 764            2           70.0           27.0      NaN  36.8
# 765            5           72.0           23.0    112.0  26.2
# 766            1           60.0            NaN      NaN  30.1
# 767            1           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# ...

# %% [markdown]
# ***INTERPOLATION(linear,polynomial)***

# %%
a = pd.Series([0,1,2,np.nan,5,6,7])

# %%
a
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# 3    NaN
# 4    5.0
# 5    6.0
# 6    7.0
# dtype: float64

# %%
a.interpolate()
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# 3    3.5
# 4    5.0
# 5    6.0
# 6    7.0
# dtype: float64

# %%
b = pd.Series([0,1,2,np.nan,6,7])

# %%
b.interpolate()
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# 3    4.0
# 4    6.0
# 5    7.0
# dtype: float64

# %%
b.interpolate(method = 'polynomial', order = 3 )
# Out:
# 0    0.000000
# 1    1.000000
# 2    2.000000
# 3    3.928571
# 4    6.000000
# 5    7.000000
# dtype: float64

# %% [markdown]
# ***KNN IMPUTER***

# %%
x ={'age': [20,40,30],'salary':[3,4.5,np.nan]}
df = pd.DataFrame(x)

# %%
df.index = [1,2,3]
df
# Out:
#    age  salary
# 1   20     3.0
# 2   40     4.5
# 3   30     NaN

# %%
df.reset_index()
# Out:
#    index  age  salary
# 0      1   20     3.0
# 1      2   40     4.5
# 2      3   30     NaN

# %%
from sklearn.impute import KNNImputeer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 from sklearn.impute import KNNImputeer
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# ***DATAFRAME ITERATION***

# %%
df =  pd.read_csv("C:\\Users\\kohit\\Downloads\\diabetes.csv" )

# %%
df

# %%
df = df.head(10)

# %%
df

# %%
#x = {'name' :['x','y','w','d','t','a','h','b','l','g']}
#df1 = pd.DataFrame(x)

# %%
df1

# %%
df3 = pd.concat((df1 + df) , axis = 1)

# %%
for index in df.index:  # IT IS BY USING INDEX
    print(df ['Glucose'][index] , df[ 'BMI'] [index ])

# %%
for i in range(len(df)):  ###BY USINF LOC FUNCTION/METHOD
    print(df.loc[i , 'Glucose'], df.loc[i , 'BMI'])

# %%
for i in range(len(df)):     ###BY USING ILOC FUNCTION/METHOD
    print(df.iloc[i , 1], df.loc[i , 5])

# %%
for x , y in df.iterrows():
    print(x ,'\n' ,y ,'\n', '***'*10)

# %%
df.head()

# %%
import seaborn as sns

# %%
def convert_age_to_category (x):
    if x< 18:
        return 'children'
    if x >= 18 and x <= 45:
        return 'adult'
    else:
        return 'old'

df['category' ] = df['Age'].apply(convert_age_to_category)

# %%
df.head()

# %%
sns.countplot(df['category'])

# %%
tf = pd.read_csv(r"C:\Users\kohit\Downloads\Titanic.csv")

# %%
tf

# %%
tf.isnull().sum()

# %%
tf = tf['Age'].fillna(tf['Age'].mean())

# %%
tf.info()

# %%
tf

# %%
df = pd.read_csv(r"C:\Users\kohit\Downloads\Titanic.csv")

# %%
updated_df = df
updated_df['Age']= updated_df['Age'].fillna(updated_df['Age'].mean())

# %%
df

# %%
df.info()

# %%
updated_df.info()
